# %% [markdown]
# <a href="https://colab.research.google.com/github/moka20030107/ml-project/blob/main/bedrize_sleep_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# まず/contentsに、https://drive.google.com/drive/folders/1OjR3rYWzAMX0yhjej0_TMDoGkgsZPG2h?usp=sharing の「参考：GoogleColab用」フォルダの中の archive.zip をアップする。

# %%
# !pip install torchinfo

# %%
# !pip install japanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 46.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=096d41669c0d083dfdbb1f7c9dd935b6147384b8d0c3755b90d23d20bcc37f43
#   Stored in directory: /root/.cache/pip/wheels/c1/f7/9b/418f19a7b9340fc16e071e89efc379aca68d40238b258df53d
# Successfully built japanize_matplotlib
# ...

# %%
# !pip install torcheval
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 11.4 MB/s eta 0:00:00
# ...

# %%
# !mkdir /content/logfile

# %%
# !unzip -d /content/ /content/archive.zip
# Out:
# Archive:  /content/archive.zip
#    creating: /content/DatasetCsv10-16/
#   inflating: /content/__MACOSX/._DatasetCsv10-16
#   inflating: /content/DatasetCsv10-16/.DS_Store
#   inflating: /content/__MACOSX/DatasetCsv10-16/._.DS_Store
#   inflating: /content/DatasetCsv10-16/dataset_thick.npy
#   inflating: /content/__MACOSX/DatasetCsv10-16/._dataset_thick.npy
#    creating: /content/DatasetCsv10-16/person5/
#   inflating: /content/__MACOSX/DatasetCsv10-16/._person5
#    creating: /content/DatasetCsv10-16/person2/
#   inflating: /content/__MACOSX/DatasetCsv10-16/._person2
#   inflating: /content/DatasetCsv10-16/dataset_thin.npy
#   inflating: /content/__MACOSX/DatasetCsv10-16/._dataset_thin.npy
#    creating: /content/DatasetCsv10-16/person3/
#   inflating: /content/__MACOSX/DatasetCsv10-16/._person3
#    creating: /content/DatasetCsv10-16/person4/
#   inflating: /content/__MACOSX/DatasetCsv10-16/._person4
#    creating: /content/DatasetCsv10-16/person1/
# ...

# %%
# !pip install timesformer_pytorch

# %%
# !python main_sleep.py
# Out:
# python3: can't open file '/content/main_sleep.py': [Errno 2] No such file or directory

# %%
# !python main_sleepVer2.py
# Out:
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/f2py/crackfortran.py", line 633, in <module>
#     datapattern = re.compile(
#                   ^^^^^^^^^^^
#   File "/usr/lib/python3.11/re/__init__.py", line 227, in compile
#     return _compile(pattern, flags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/re/__init__.py", line 294, in _compile
#     p = _compiler.compile(pattern, flags)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/re/_compiler.py", line 745, in compile
#     p = _parser.parse(p, flags)
#         ^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !python main_sleepVer3.py
# Out:
# [実行] トリミング処理中 → ./DatasetCsv10-16/dataset_no.npy
# [保存完了] ./DatasetCsv10-16/dataset_no_trimmed.npy | shape: (529, 32, 225)
# [実行] トリミング処理中 → ./DatasetCsv10-16/dataset_thin.npy
# [保存完了] ./DatasetCsv10-16/dataset_thin_trimmed.npy | shape: (463, 32, 225)
# [実行] トリミング処理中 → ./DatasetCsv10-16/dataset_thick.npy
# [保存完了] ./DatasetCsv10-16/dataset_thick_trimmed.npy | shape: (446, 32, 225)
# training start
# best_acc:0.75
# Precision: 0.6346153616905212
# Recall: 0.7857142686843872
# F1_score: 0.7021276950836182
# training start
# best_acc:0.7410714285714286
# Precision: 0.75
# Recall: 0.7090908885002136
# F1_score: 0.7289718985557556
# training start
# best_acc:0.7678571428571429
# Precision: 0.8269230723381042
# Recall: 0.7166666388511658
# F1_score: 0.7678571343421936
# training start
# best_acc:0.7589285714285714
# Precision: 0.807692289352417
# Recall: 0.7118644118309021
# F1_score: 0.7567567229270935
# training start
# best_acc:0.7142857142857143
# Precision: 0.7115384340286255
# ...

# %%
# !python main_sleepVer4.py
# Out:
# Traceback (most recent call last):
#   File "/content/main_sleepVer4.py", line 3, in <module>
#     from dataVer4 import *
#   File "/content/dataVer4.py", line 2, in <module>
#     import torch
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2604, in <module>
#     from torch import _meta_registrations
#   File "/usr/local/lib/python3.11/dist-packages/torch/_meta_registrations.py", line 11, in <module>
#     from torch._decomp import (
#   File "/usr/local/lib/python3.11/dist-packages/torch/_decomp/__init__.py", line 284, in <module>
#     import torch._decomp.decompositions
#   File "/usr/local/lib/python3.11/dist-packages/torch/_decomp/decompositions.py", line 15, in <module>
#     import torch._prims as prims
#   File "/usr/local/lib/python3.11/dist-packages/torch/_prims/__init__.py", line 974, in <module>
#     bitwise_and = _make_elementwise_binary_prim(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !python main_sleepVer5.py
# Out:
# Traceback (most recent call last):
#   File "/content/main_sleepVer5.py", line 3, in <module>
#     from dataVer5 import *
#   File "/content/dataVer5.py", line 2, in <module>
#     import torch
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2604, in <module>
#     from torch import _meta_registrations
#   File "/usr/local/lib/python3.11/dist-packages/torch/_meta_registrations.py", line 11, in <module>
#     from torch._decomp import (
#   File "/usr/local/lib/python3.11/dist-packages/torch/_decomp/__init__.py", line 284, in <module>
#     import torch._decomp.decompositions
#   File "/usr/local/lib/python3.11/dist-packages/torch/_decomp/decompositions.py", line 15, in <module>
#     import torch._prims as prims
#   File "/usr/local/lib/python3.11/dist-packages/torch/_prims/__init__.py", line 1841, in <module>
#     reshape = _make_prim(
#               ^^^^^^^^^^^
# ...
